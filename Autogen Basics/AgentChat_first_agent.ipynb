# %%
from autogen_agentchat.agents import AssistantAgent

# %%
from autogen_ext.models.openai import OpenAIChatCompletionClient

# %%
from dotenv import load_dotenv
import os
api_key  = os.getenv("OPENAI_API_KEY")

# %%
print(api_key)
# Out:
# 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

# %%
model_client = OpenAIChatCompletionClient(model="gpt-4o-mini",api_key=api_key)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 model_client = OpenAIChatCompletionClient(model="gpt-3.5",api_key=api_key)
#
# File c:\Users\ADMIN\Desktop\Project\Autogen_AgenticAI\.venv\Lib\site-packages\autogen_ext\models\openai\_openai_client.py:1394, in OpenAIChatCompletionClient.__init__(self, **kwargs)
#    1391 client = _openai_client_from_config(copied_args)
#    1392 create_args = _create_args_from_config(copied_args)
# -> 1394 super().__init__(
#    1395     client=client,
#    1396     create_args=create_args,
#    1397     model_capabilities=model_capabilities,
#    1398     model_info=model_info,
#    1399     add_name_prefixes=add_name_prefixes,
#    1400 )
#
# ...

# %%
assistant  = AssistantAgent(name = 'assistant',model_client = model_client)

# %%
from autogen_ext.models.openai import OpenAIChatCompletionClient

model_client = OpenAIChatCompletionClient(model = "gpt-4o-mini",api_key = api_key)

assistant  = AssistantAgent(name = 'assistant',model_client = model_client)

result = await assistant.run(task = "what is capital of India?  ")
print(result[-1].content)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[19], line 7
#       3 model_client = OpenAIChatCompletionClient(model = "gpt-4o-mini",api_key = api_key)
#       5 assistant  = AssistantAgent(name = 'assistant',model_client = model_client)
# ----> 7 result = await assistant.run(task = "what is capital of India?  ")
#       8 print(result[-1].content)
#
# File c:\Users\ADMIN\Desktop\Project\Autogen_AgenticAI\.venv\Lib\site-packages\autogen_agentchat\agents\_base_chat_agent.py:136, in BaseChatAgent.run(self, task, cancellation_token)
#     134         else:
#     135             raise ValueError(f"Invalid message type in sequence: {type(msg)}")
# --> 136 response = await self.on_messages(input_messages, cancellation_token)
#     137 if response.inner_messages is not None:
#     138     output_messages += response.inner_messages
#
# ...

# %%
### USING Gemini api key

from autogen_agentchat.agents import AssistantAgent
from autogen_ext.models.openai import OpenAIChatCompletionClient
from dotenv import load_dotenv
import os
load_dotenv()
google_api_key = os.getenv("GEMINI_KEY")

print(f"api key is {google_api_key} ")

model_client = OpenAIChatCompletionClient(model = "gemini-2.0-flash",api_key = google_api_key)
# Out:
# api key is AIzaSyDsIcBSy9KNdsJrRTbd_5v4yA6bQXQa6HM

# %%
from autogen_agentchat import messages


assistant = AssistantAgent(name = "assistant",model_client = model_client)
result = await assistant.run(task = "what is capital of Andhra Pradesh  ?  ")
print(result.messages[-1].content)
# Out:
# Amaravati is the capital of Andhra Pradesh.
